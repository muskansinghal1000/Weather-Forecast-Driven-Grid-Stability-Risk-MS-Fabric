# %%
# Load the shortcut table
df = spark.read.load("Tables/gold_weatherdata_current_shortcut")

# Save as Delta in your Lakehouse
df.write.format("delta").save("Tables/gold_weatherdata_current_shortcutDelta")
# Out:
# StatementMeta(, 3384d69b-e918-4a07-9af6-2f59b7ce08c2, 3, Finished, Available, Finished)
